# %% [markdown]
# # End-to-End Data Cleaning Pipeline with Raha and Baran (Minimal and Sequential)
# We build an end-to-end data cleaning pipeline with our configuration-free error detection and correction systems, Raha and Baran.

# %%
import pandas
import IPython.display

import raha

# %% [markdown]
# ## Error Detection with Raha

# %% [markdown]
# ### 1. Instantiating the Detection Class
# We first instantiate the `Detection` class.

# %%
app_1 = raha.Detection()

# How many tuples would you label?
app_1.LABELING_BUDGET = 20

# Would you like to see the logs?
app_1.VERBOSE = True

# %% [markdown]
# ### 2. Instantiating the Dataset
# We next load and instantiate the dataset object.

# %%
dataset_dictionary = {
    "name": "flights",
    "path": "../datasets/flights/dirty.csv",
    "clean_path": "../datasets/flights/clean.csv"
}
d = app_1.initialize_dataset(dataset_dictionary)
d.dataframe.head()
# Out:
#   tuple_id src           flight sched_dep_time act_dep_time sched_arr_time  \
# 0        1  aa  AA-3859-IAH-ORD      7:10 a.m.    7:16 a.m.      9:40 a.m.
# 1        2  aa  AA-1733-ORD-PHX      7:45 p.m.    7:58 p.m.     10:30 p.m.
# 2        3  aa  AA-1640-MIA-MCO      6:30 p.m.                   7:25 p.m.
# 3        4  aa   AA-518-MIA-JFK      6:40 a.m.    6:54 a.m.      9:25 a.m.
# 4        5  aa  AA-3756-ORD-SLC     12:15 p.m.   12:41 p.m.      2:45 p.m.
#
#   act_arr_time
# 0    9:32 a.m.
# 1
# 2
# 3    9:28 a.m.
# 4    2:50 p.m.

# %%
d.dataframe
# Out:
#      tuple_id                   src           flight sched_dep_time  \
# 0           1                    aa  AA-3859-IAH-ORD      7:10 a.m.
# 1           2                    aa  AA-1733-ORD-PHX      7:45 p.m.
# 2           3                    aa  AA-1640-MIA-MCO      6:30 p.m.
# 3           4                    aa   AA-518-MIA-JFK      6:40 a.m.
# 4           5                    aa  AA-3756-ORD-SLC     12:15 p.m.
# ...       ...                   ...              ...            ...
# 2371     2372  world-flight-tracker  UA-3099-PHX-PHL     11:55 a.m.
# 2372     2373  world-flight-tracker  AA-4198-ORD-CLE     10:40 a.m.
# 2373     2374  world-flight-tracker    CO-45-EWR-MIA      4:00 p.m.
# 2374     2375  world-flight-tracker  AA-3809-PHX-LAX      6:00 a.m.
# 2375     2376  world-flight-tracker    AA-59-JFK-SFO      7:10 a.m.
#
#      act_dep_time sched_arr_time act_arr_time
# 0       7:16 a.m.      9:40 a.m.    9:32 a.m.
# 1       7:58 p.m.     10:30 p.m.
# 2                      7:25 p.m.
# 3       6:54 a.m.      9:25 a.m.    9:28 a.m.
# 4      12:41 p.m.      2:45 p.m.    2:50 p.m.
# ...           ...            ...          ...
# 2371   11:43 a.m.      6:17 p.m.    5:38 p.m.
# 2372   10:54 a.m.     12:55 p.m.   12:50 p.m.
# 2373    3:58 p.m.      7:05 p.m.    6:36 p.m.
# 2374    6:10 a.m.      6:40 a.m.    6:19 a.m.
# 2375    7:39 a.m.     10:45 a.m.   11:12 a.m.
#
# [2376 rows x 7 columns]

# %% [markdown]
# ### 3. Running Error Detection Strategies
# Raha runs (all or the promising) error detection strategies on the dataset. This step could take a while because all the strategies should be run on the dataset.

# %%
app_1.run_strategies(d)
# Out:
# 99 cells are detected by ["PVD", ["src", "z"]].498 cells are detected by ["PVD", ["flight", "P"]].
#
# 616 cells are detected by ["PVD", ["tuple_id", "4"]].
# 2 cells are detected by ["PVD", ["sched_arr_time", "P"]].871 cells are detected by ["PVD", ["flight", "4"]].
#
# 348 cells are detected by ["PVD", ["act_arr_time", "7"]].
# 85 cells are detected by ["PVD", ["sched_dep_time", "e"]].
# 745 cells are detected by ["PVD", ["src", "h"]].
# 2 cells are detected by ["PVD", ["sched_dep_time", "n"]].
# 436 cells are detected by ["PVD", ["src", "c"]].
# 591 cells are detected by ["PVD", ["act_arr_time", "4"]].
# 131 cells are detected by ["PVD", ["sched_dep_time", "9"]].
# 36 cells are detected by ["PVD", ["act_dep_time", "d"]].
# 2329 cells are detected by ["PVD", ["flight", "A"]].
# 35 cells are detected by ["PVD", ["act_dep_time", ")"]].196 cells are detected by ["PVD", ["sched_dep_time", "6"]].
#
# 741 cells are detected by ["PVD", ["sched_arr_time", "0"]].
# 1503 cells are detected by ["PVD", ["sched_dep_time", "m"]].
# 1989 cells are detected by ["PVD", ["act_arr_time", " "]].37 cells are detected by ["PVD", ["act_dep_time", "l"]].
#
# 32 cells are detected by ["PVD", ["act_dep_time", "A"]].
# 31 cells are detected by ["PVD", ["act_dep_time", "s"]].13 cells are detected by ["PVD", ["sched_dep_time", "l"]].
#
# 1106 cells are detected by ["PVD", ["flight", "D"]].
# 42 cells are detected by ["PVD", ["act_arr_time", "d"]].
# 677 cells are detected by ["PVD", ["flight", "8"]].
# 13 cells are detected by ["PVD", ["sched_arr_time", "b"]].874 cells are detected by ["PVD", ["flight", "H"]].1375 cells are detected by ["PVD", ["src", "l"]].
#
#
# 24 cells are detected by ["PVD", ["act_dep_time", "w"]].139 cells are detected by ["PVD", ["act_dep_time", "e"]].
#
# 23 cells are detected by ["PVD", ["sched_arr_time", "/"]].
# 709 cells are detected by ["PVD", ["flight", "M"]].805 cells are detected by ["PVD", ["act_arr_time", "a"]].
#
# 13 cells are detected by ["PVD", ["sched_arr_time", "v"]].
# 331 cells are detected by ["PVD", ["sched_dep_time", "7"]].117 cells are detected by ["PVD", ["sched_arr_time", "D"]].
#
# 547 cells are detected by ["PVD", ["flight", "7"]].
# 627 cells are detected by ["PVD", ["sched_arr_time", "a"]].
# 29 cells are detected by ["PVD", ["act_dep_time", "y"]].
# 55 cells are detected by ["PVD", ["src", "-"]].
# 676 cells are detected by ["PVD", ["tuple_id", "3"]].
# 689 cells are detected by ["PVD", ["flight", "U"]].
# 1525 cells are detected by ["PVD", ["sched_arr_time", "m"]].
# 470 cells are detected by ["PVD", ["act_arr_time", "9"]].
# 145 cells are detected by ["PVD", ["flight", "V"]].
# 1503 cells are detected by ["PVD", ["sched_dep_time", "."]].
# 162 cells are detected by ["PVD", ["flight", "G"]].
# 0 cells are detected by ["RVD", ["tuple_id", "sched_dep_time"]].
#
# 44 cells are detected by ["PVD", ["act_arr_time", "n"]].
# 0 cells are detected by ["RVD", ["tuple_id", "act_arr_time"]].331 cells are detected by ["PVD", ["sched_dep_time", "4"]].
# 616 cells are detected by ["PVD", ["tuple_id", "6"]].
# 539 cells are detected by ["PVD", ["flight", "0"]].603 cells are detected by ["PVD", ["act_arr_time", "5"]].
#
# 13 cells are detected by ["PVD", ["sched_dep_time", "t"]].
# 30 cells are detected by ["PVD", ["sched_arr_time", "i"]].
# 676 cells are detected by ["PVD", ["act_arr_time", "3"]].
# 956 cells are detected by ["PVD", ["act_arr_time", "1"]].
# 885 cells are detected by ["PVD", ["sched_arr_time", "5"]].
# 20 cells are detected by ["PVD", ["sched_arr_time", "-"]].13 cells are detected by ["PVD", ["sched_dep_time", "A"]].
#
# 451 cells are detected by ["PVD", ["sched_arr_time", "3"]].
# 473 cells are detected by ["PVD", ["act_dep_time", "8"]].
# 637 cells are detected by ["PVD", ["act_dep_time", "0"]].
# 821 cells are detected by ["PVD", ["src", "n"]].
# 1118 cells are detected by ["PVD", ["act_dep_time", "a"]].
# 18 cells are detected by ["PVD", ["act_dep_time", "N"]].
# 13 cells are detected by ["PVD", ["sched_arr_time", "t"]].
# 967 cells are detected by ["PVD", ["sched_arr_time", "p"]].
# 283 cells are detected by ["PVD", ["flight", "T"]].409 cells are detected by ["PVD", ["sched_dep_time", "2"]].
#
# 279 cells are detected by ["PVD", ["flight", "J"]].
# 7 cells are detected by ["PVD", ["sched_arr_time", "u"]].
# 955 cells are detected by ["PVD", ["act_dep_time", "1"]].
# 24 cells are detected by ["PVD", ["act_dep_time", "u"]].7 cells are detected by ["PVD", ["sched_arr_time", "h"]].13 cells are detected by ["PVD", ["sched_arr_time", "o"]].
# 174 cells are detected by ["PVD", ["sched_dep_time", "8"]].669 cells are detected by ["PVD", ["flight", "5"]].
#
#
#
# 13 cells are detected by ["PVD", ["sched_dep_time", "N"]].
# 163 cells are detected by ["PVD", ["flight", "N"]].18 cells are detected by ["PVD", ["act_dep_time", "b"]].
#
# 13 cells are detected by ["PVD", ["sched_arr_time", "N"]].
# 106 cells are detected by ["PVD", ["sched_arr_time", "8"]].63 cells are detected by ["PVD", ["act_dep_time", "t"]].
#
# 14 cells are detected by ["PVD", ["act_arr_time", "C"]].
# 72 cells are detected by ["PVD", ["sched_dep_time", "c"]].
# 72 cells are detected by ["PVD", ["sched_dep_time", "D"]].
# 17 cells are detected by ["PVD", ["sched_arr_time", "F"]].
# 506 cells are detected by ["PVD", ["flight", "S"]].
# 1 cells are detected by ["PVD", ["act_dep_time", "T"]].
# 3836 cells are detected by ["RVD", ["act_dep_time", "src"]].
# 1 cells are detected by ["PVD", ["sched_dep_time", "h"]].
# 259 cells are detected by ["PVD", ["src", "d"]].
# 670 cells are detected by ["RVD", ["sched_arr_time", "flight"]].
# 397 cells are detected by ["PVD", ["flight", "E"]].8 cells are detected by ["PVD", ["act_arr_time", "/"]].
#
# 30 cells are detected by ["PVD", ["act_arr_time", "y"]].
# 31 cells are detected by ["PVD", ["act_dep_time", "E"]].14 cells are detected by ["PVD", ["act_dep_time", "C"]].
#
# 1525 cells are detected by ["PVD", ["sched_arr_time", "."]].
# 1020 cells are detected by ["PVD", ["src", "g"]].
# 18 cells are detected by ["PVD", ["act_arr_time", "N"]].1205 cells are detected by ["PVD", ["src", "o"]].
#
# 409 cells are detected by ["PVD", ["src", "p"]].527 cells are detected by ["PVD", ["sched_arr_time", "2"]].
#
# 1 cells are detected by ["PVD", ["act_arr_time", "\u00a0"]].
# 35 cells are detected by ["PVD", ["act_arr_time", "A"]].
# 229 cells are detected by ["PVD", ["sched_arr_time", "7"]].
# 3116 cells are detected by ["RVD", ["sched_dep_time", "tuple_id"]].92 cells are detected by ["PVD", ["src", "q"]].
#
# 74 cells are detected by ["PVD", ["act_arr_time", "t"]].
# 48 cells are detected by ["PVD", ["act_arr_time", ")"]].
# 0 cells are detected by ["RVD", ["tuple_id", "src"]].
# 797 cells are detected by ["PVD", ["sched_dep_time", "p"]].1209 cells are detected by ["PVD", ["act_arr_time", "p"]].
#
# 352 cells are detected by ["PVD", ["sched_dep_time", "3"]].
# 4636 cells are detected by ["RVD", ["src", "act_dep_time"]].
# 3 cells are detected by ["PVD", ["act_arr_time", "R"]].
# 437 cells are detected by ["PVD", ["sched_arr_time", "4"]].
# 117 cells are detected by ["PVD", ["sched_arr_time", "c"]].
# 729 cells are detected by ["PVD", ["sched_arr_time", "1"]].
# 42 cells are detected by ["PVD", ["act_arr_time", "s"]].
# 1716 cells are detected by ["PVD", ["src", "t"]].
# 4750 cells are detected by ["RVD", ["src", "tuple_id"]].
# 1540 cells are detected by ["PVD", ["flight", "O"]].
# 18 cells are detected by ["PVD", ["act_arr_time", "v"]].
# 1110 cells are detected by ["RVD", ["sched_dep_time", "flight"]].
# 4 cells are detected by ["PVD", ["act_dep_time", "+"]].2 cells are detected by ["PVD", ["act_arr_time", "P"]].
#
# 542 cells are detected by ["PVD", ["src", "u"]].
# 616 cells are detected by ["PVD", ["tuple_id", "5"]].
# 264 cells are detected by ["PVD", ["sched_arr_time", "9"]].
# 476 cells are detected by ["PVD", ["act_dep_time", "7"]].
# 1589 cells are detected by ["PVD", ["sched_dep_time", " "]].
# 1 cells are detected by ["PVD", ["sched_dep_time", "T"]].
# 1 cells are detected by ["PVD", ["sched_dep_time", "u"]].
# 590 cells are detected by ["PVD", ["flight", "X"]].
# 6 cells are detected by ["PVD", ["act_arr_time", "h"]].
# 821 cells are detected by ["PVD", ["sched_dep_time", "5"]].
# 38 cells are detected by ["PVD", ["act_dep_time", "r"]].4 cells are detected by ["PVD", ["sched_dep_time", ")"]].
#
# 16 cells are detected by ["PVD", ["sched_arr_time", "A"]].13 cells are detected by ["PVD", ["sched_dep_time", "b"]].
#
# 42 cells are detected by ["PVD", ["act_arr_time", "E"]].13 cells are detected by ["PVD", ["sched_dep_time", "v"]].
#
# 117 cells are detected by ["PVD", ["act_arr_time", "e"]].
# 905 cells are detected by ["PVD", ["flight", "3"]].4752 cells are detected by ["RVD", ["flight", "act_dep_time"]].
#
# 562 cells are detected by ["PVD", ["act_dep_time", "5"]].
# 1606 cells are detected by ["PVD", ["sched_arr_time", " "]].
# 32 cells are detected by ["PVD", ["act_dep_time", "o"]].
# 76 cells are detected by ["PVD", ["act_arr_time", "i"]].
# 628 cells are detected by ["PVD", ["flight", "6"]].
# 952 cells are detected by ["PVD", ["flight", "I"]].
# 64 cells are detected by ["PVD", ["act_dep_time", "i"]].
# 659 cells are detected by ["PVD", ["act_arr_time", "0"]].
# 84 cells are detected by ["PVD", ["act_dep_time", "c"]].
# 2830 cells are detected by ["RVD", ["sched_dep_time", "act_arr_time"]].
# 4752 cells are detected by ["RVD", ["flight", "act_arr_time"]].
# 1999 cells are detected by ["PVD", ["act_dep_time", " "]].
# 32 cells are detected by ["PVD", ["act_arr_time", "o"]].
# 791 cells are detected by ["PVD", ["sched_dep_time", "a"]].
# 48 cells are detected by ["PVD", ["act_arr_time", "("]].
# 0 cells are detected by ["RVD", ["tuple_id", "act_dep_time"]].
# 1593 cells are detected by ["PVD", ["sched_arr_time", ":"]].
# 226 cells are detected by ["PVD", ["sched_arr_time", "6"]].
# 18 cells are detected by ["PVD", ["act_arr_time", "b"]].
# 1962 cells are detected by ["PVD", ["act_arr_time", ":"]].263 cells are detected by ["PVD", ["src", "x"]].130 cells are detected by ["PVD", ["sched_arr_time", "e"]].
#
#
# 3098 cells are detected by ["RVD", ["sched_dep_time", "src"]].
# 1897 cells are detected by ["PVD", ["act_dep_time", "."]].
# 4 cells are detected by ["PVD", ["sched_dep_time", "("]].
# 2376 cells are detected by ["PVD", ["flight", "-"]].
# 912 cells are detected by ["PVD", ["act_dep_time", "p"]].
# 1141 cells are detected by ["PVD", ["src", "r"]].
# 258 cells are detected by ["PVD", ["act_dep_time", "9"]].
# 399 cells are detected by ["PVD", ["src", "w"]].
# 1968 cells are detected by ["PVD", ["act_dep_time", ":"]].
# 764 cells are detected by ["PVD", ["act_dep_time", "2"]].
# 1172 cells are detected by ["RVD", ["sched_arr_time", "sched_dep_time"]].
# 279 cells are detected by ["PVD", ["flight", "K"]].
# 602 cells are detected by ["PVD", ["act_dep_time", "4"]].
# 1082 cells are detected by ["RVD", ["act_dep_time", "sched_dep_time"]].
# 100 cells are detected by ["PVD", ["src", "j"]].
# 889 cells are detected by ["PVD", ["sched_dep_time", "0"]].
# 61 cells are detected by ["PVD", ["act_arr_time", "c"]].
# 2682 cells are detected by ["RVD", ["act_arr_time", "act_dep_time"]].7 cells are detected by ["PVD", ["sched_arr_time", "T"]].
#
# 1910 cells are detected by ["PVD", ["act_arr_time", "m"]].
# 2728 cells are detected by ["RVD", ["sched_dep_time", "sched_arr_time"]].
# 17 cells are detected by ["PVD", ["sched_arr_time", "r"]].
# 13 cells are detected by ["PVD", ["sched_arr_time", "l"]].
# 4750 cells are detected by ["RVD", ["src", "flight"]].
# 35 cells are detected by ["PVD", ["act_dep_time", "("]].
# 2144 cells are detected by ["RVD", ["sched_arr_time", "act_arr_time"]].
# 48 cells are detected by ["PVD", ["act_arr_time", "D"]].
# 220 cells are detected by ["PVD", ["act_arr_time", "8"]].
# 86 cells are detected by ["PVD", ["flight", "B"]].1518 cells are detected by ["PVD", ["src", "i"]].
#
# 950 cells are detected by ["PVD", ["flight", "C"]].
# 2 cells are detected by ["PVD", ["act_arr_time", "*"]].
# 405 cells are detected by ["PVD", ["act_arr_time", "6"]].
# 15 cells are detected by ["PVD", ["sched_dep_time", "o"]].
# 75 cells are detected by ["PVD", ["act_dep_time", "D"]].
# 36 cells are detected by ["PVD", ["act_arr_time", "u"]].
# 3112 cells are detected by ["RVD", ["sched_arr_time", "tuple_id"]].
# 620 cells are detected by ["PVD", ["src", "y"]].0 cells are detected by ["RVD", ["tuple_id", "sched_arr_time"]].
#
# 4 cells are detected by ["PVD", ["sched_dep_time", "-"]].
# 671 cells are detected by ["PVD", ["src", "s"]].
# 907 cells are detected by ["PVD", ["flight", "R"]].
# 1426 cells are detected by ["PVD", ["tuple_id", "1"]].
# 19 cells are detected by ["PVD", ["src", "C"]].
# 1 cells are detected by ["PVD", ["act_dep_time", "/"]].
# 828 cells are detected by ["PVD", ["flight", "L"]].732 cells are detected by ["PVD", ["flight", "F"]].
#
# 43 cells are detected by ["PVD", ["act_arr_time", "r"]].
# 1940 cells are detected by ["RVD", ["act_dep_time", "sched_arr_time"]].
# 770 cells are detected by ["PVD", ["sched_dep_time", "1"]].
# 1579 cells are detected by ["PVD", ["sched_dep_time", ":"]].3108 cells are detected by ["RVD", ["sched_arr_time", "src"]].
#
# 606 cells are detected by ["PVD", ["tuple_id", "9"]].
# 1910 cells are detected by ["PVD", ["act_arr_time", "."]].
# 495 cells are detected by ["PVD", ["flight", "9"]].
# 30 cells are detected by ["PVD", ["act_arr_time", "w"]].
# 13 cells are detected by ["PVD", ["sched_dep_time", "i"]].
# 539 cells are detected by ["PVD", ["src", "v"]].
# 557 cells are detected by ["PVD", ["flight", "W"]].
# 399 cells are detected by ["PVD", ["src", "b"]].
# 18 cells are detected by ["PVD", ["act_dep_time", "v"]].
# 796 cells are detected by ["PVD", ["flight", "1"]].1132 cells are detected by ["RVD", ["act_arr_time", "sched_arr_time"]].
#
# 3834 cells are detected by ["RVD", ["act_arr_time", "src"]].3838 cells are detected by ["RVD", ["act_arr_time", "tuple_id"]].
#
# 638 cells are detected by ["PVD", ["act_arr_time", "2"]].
# 811 cells are detected by ["PVD", ["flight", "2"]].
# 383 cells are detected by ["PVD", ["act_dep_time", "6"]].
# 1550 cells are detected by ["RVD", ["act_dep_time", "flight"]].1304 cells are detected by ["RVD", ["act_arr_time", "sched_dep_time"]].
#
# 1393 cells are detected by ["PVD", ["src", "e"]].
# 4210 cells are detected by ["RVD", ["flight", "sched_arr_time"]].
# 613 cells are detected by ["PVD", ["tuple_id", "7"]].
# 39 cells are detected by ["PVD", ["flight", "Y"]].
# 263 cells are detected by ["PVD", ["src", "m"]].
# 3232 cells are detected by ["RVD", ["flight", "sched_dep_time"]].
# 1129 cells are detected by ["PVD", ["src", "a"]].
# 147 cells are detected by ["PVD", ["src", "k"]].
# 606 cells are detected by ["PVD", ["tuple_id", "8"]].
# 39 cells are detected by ["PVD", ["act_dep_time", "n"]].
# 964 cells are detected by ["RVD", ["act_arr_time", "flight"]].
# 2836 cells are detected by ["RVD", ["sched_dep_time", "act_dep_time"]].
# 10 cells are detected by ["PVD", ["sched_dep_time", "/"]].
# 1101 cells are detected by ["PVD", ["src", "f"]].
# 32 cells are detected by ["PVD", ["act_arr_time", "l"]].
# 1 cells are detected by ["PVD", ["act_dep_time", "O"]].
# 919 cells are detected by ["PVD", ["tuple_id", "2"]].
# 19 cells are detected by ["PVD", ["src", "O"]].
# 0 cells are detected by ["RVD", ["tuple_id", "flight"]].
# 606 cells are detected by ["PVD", ["tuple_id", "0"]].
# 508 cells are detected by ["PVD", ["act_dep_time", "3"]].
# 1897 cells are detected by ["PVD", ["act_dep_time", "m"]].2 cells are detected by ["PVD", ["act_arr_time", "F"]].
# 2378 cells are detected by ["RVD", ["sched_arr_time", "act_dep_time"]].
#
# 6 cells are detected by ["PVD", ["act_arr_time", "T"]].
# 4704 cells are detected by ["RVD", ["src", "sched_dep_time"]].
# 2978 cells are detected by ["RVD", ["act_dep_time", "act_arr_time"]].
# 4752 cells are detected by ["RVD", ["flight", "tuple_id"]].3852 cells are detected by ["RVD", ["act_dep_time", "tuple_id"]].
#
# 1635 cells are detected by ["KBVD", "/home/yanmy/anaconda3/lib/python3.9/site-packages/raha/tools/KATARA/knowledge-base/zipHasCity.rel.txt"].
# 4752 cells are detected by ["RVD", ["flight", "src"]].
# 4740 cells are detected by ["RVD", ["src", "sched_arr_time"]].
# 4662 cells are detected by ["RVD", ["src", "act_arr_time"]].
# 794 cells are detected by ["OD", ["gaussian", "2.3"]].
# 6724 cells are detected by ["OD", ["histogram", "0.1", "0.3"]].
# 258 cells are detected by ["OD", ["gaussian", "2.7"]].
# 248 cells are detected by ["OD", ["gaussian", "3.0"]].
# 3904 cells are detected by ["OD", ["gaussian", "1.0"]].
# 693 cells are detected by ["OD", ["histogram", "0.7", "0.1"]].
# 6724 cells are detected by ["OD", ["histogram", "0.3", "0.3"]].
# 14275 cells are detected by ["OD", ["histogram", "0.5", "0.9"]].14769 cells are detected by ["OD", ["histogram", "0.3", "0.7"]].
#
# 1333 cells are detected by ["OD", ["gaussian", "2.0"]].
# 9566 cells are detected by ["OD", ["histogram", "0.9", "0.9"]].
# 668 cells are detected by ["OD", ["histogram", "0.9", "0.1"]].
# 2238 cells are detected by ["OD", ["histogram", "0.1", "0.1"]].
# 4367 cells are detected by ["OD", ["histogram", "0.7", "0.3"]].
# 1849 cells are detected by ["OD", ["gaussian", "1.7"]].
# 3585 cells are detected by ["OD", ["gaussian", "1.3"]].
# 12001 cells are detected by ["OD", ["histogram", "0.3", "0.5"]].
# 2934 cells are detected by ["OD", ["histogram", "0.9", "0.3"]].
# 357 cells are detected by ["OD", ["gaussian", "2.5"]].
# 4367 cells are detected by ["OD", ["histogram", "0.5", "0.3"]].
# 16632 cells are detected by ["OD", ["histogram", "0.1", "0.9"]].
# 8189 cells are detected by ["OD", ["histogram", "0.9", "0.5"]].
# 1922 cells are detected by ["OD", ["gaussian", "1.5"]].
# 12001 cells are detected by ["OD", ["histogram", "0.1", "0.5"]].
# 14769 cells are detected by ["OD", ["histogram", "0.1", "0.7"]].
# 2238 cells are detected by ["OD", ["histogram", "0.3", "0.1"]].
# 9566 cells are detected by ["OD", ["histogram", "0.9", "0.7"]].
# 9644 cells are detected by ["OD", ["histogram", "0.5", "0.5"]].
# 9644 cells are detected by ["OD", ["histogram", "0.7", "0.5"]].
# 693 cells are detected by ["OD", ["histogram", "0.5", "0.1"]].
# 12412 cells are detected by ["OD", ["histogram", "0.7", "0.7"]].
# 14275 cells are detected by ["OD", ["histogram", "0.7", "0.9"]].
# 12412 cells are detected by ["OD", ["histogram", "0.5", "0.7"]].
# 16632 cells are detected by ["OD", ["histogram", "0.3", "0.9"]].
# 309 strategy profiles are collected.

# %% [markdown]
# ### 4. Generating Features
# Raha then generates a feature vector for each data cell based on the output of error detection strategies.

# %%
app_1.generate_features(d)
# Out:
# 40 Features are generated for column 0.
# 65 Features are generated for column 1.
# 62 Features are generated for column 2.
# 65 Features are generated for column 3.
# 71 Features are generated for column 4.
# 65 Features are generated for column 5.
# 86 Features are generated for column 6.

# %% [markdown]
# ### 5. Building Clusters
# Raha next builds a hierarchical clustering model for our clustering-based sampling approach.

# %%
app_1.build_clusters(d)
# Out:
# A hierarchical clustering model is built for column 0.
# A hierarchical clustering model is built for column 1.
# A hierarchical clustering model is built for column 2.
# A hierarchical clustering model is built for column 3.
# A hierarchical clustering model is built for column 4.
# A hierarchical clustering model is built for column 5.
# A hierarchical clustering model is built for column 6.

# %% [markdown]
# ### 6. Interactive Tuple Sampling and Labeling
# Raha then iteratively samples a tuple. We should label data cells of each sampled tuple.

# %%
while len(d.labeled_tuples) < app_1.LABELING_BUDGET:
    app_1.sample_tuple(d)
    if d.has_ground_truth:
        app_1.label_with_ground_truth(d)
    else:
        print("Label the dirty cells in the following sampled tuple.")
        sampled_tuple = pandas.DataFrame(data=[d.dataframe.iloc[d.sampled_tuple, :]], columns=d.dataframe.columns)
        IPython.display.display(sampled_tuple)
        for j in range(d.dataframe.shape[1]):
            cell = (d.sampled_tuple, j)
            value = d.dataframe.iloc[cell]
            correction = input("What is the correction for value '{}'? Type in the same value if it is not erronous.\n".format(value))
            user_label = 1 if value != correction else 0
            d.labeled_cells[cell] = [user_label, correction]
        d.labeled_tuples[d.sampled_tuple] = 1
# Out:
# Tuple 2250 is sampled.
# Tuple 2250 is labeled.
# Tuple 1010 is sampled.
# Tuple 1010 is labeled.
# Tuple 712 is sampled.
# Tuple 712 is labeled.
# Tuple 225 is sampled.
# Tuple 225 is labeled.
# Tuple 1424 is sampled.
# Tuple 1424 is labeled.
# Tuple 2175 is sampled.
# Tuple 2175 is labeled.
# Tuple 2343 is sampled.
# Tuple 2343 is labeled.
# Tuple 1325 is sampled.
# Tuple 1325 is labeled.
# Tuple 2076 is sampled.
# Tuple 2076 is labeled.
# Tuple 597 is sampled.
# Tuple 597 is labeled.
# Tuple 1801 is sampled.
# Tuple 1801 is labeled.
# Tuple 1058 is sampled.
# Tuple 1058 is labeled.
# Tuple 1991 is sampled.
# Tuple 1991 is labeled.
# Tuple 1381 is sampled.
# Tuple 1381 is labeled.
# Tuple 1467 is sampled.
# Tuple 1467 is labeled.
# Tuple 795 is sampled.
# Tuple 795 is labeled.
# Tuple 518 is sampled.
# Tuple 518 is labeled.
# Tuple 1502 is sampled.
# Tuple 1502 is labeled.
# Tuple 899 is sampled.
# Tuple 899 is labeled.
# Tuple 244 is sampled.
# Tuple 244 is labeled.

# %% [markdown]
# Tuple 1234 is sampled.
# Tuple 1234 is labeled.
# Tuple 1385 is sampled.
# Tuple 1385 is labeled.
# Tuple 179 is sampled.
# Tuple 179 is labeled.
# Tuple 816 is sampled.
# Tuple 816 is labeled.
# Tuple 2358 is sampled.
# Tuple 2358 is labeled.
# Tuple 476 is sampled.
# Tuple 476 is labeled.
# Tuple 1415 is sampled.
# Tuple 1415 is labeled.
# Tuple 989 is sampled.
# Tuple 989 is labeled.
# Tuple 610 is sampled.
# Tuple 610 is labeled.
# Tuple 1304 is sampled.
# Tuple 1304 is labeled.
# Tuple 1973 is sampled.
# Tuple 1973 is labeled.
# Tuple 1874 is sampled.
# Tuple 1874 is labeled.
# Tuple 1126 is sampled.
# Tuple 1126 is labeled.
# Tuple 1789 is sampled.
# Tuple 1789 is labeled.
# Tuple 1672 is sampled.
# Tuple 1672 is labeled.
# Tuple 796 is sampled.
# Tuple 796 is labeled.
# Tuple 821 is sampled.
# Tuple 821 is labeled.
# Tuple 2192 is sampled.
# Tuple 2192 is labeled.
# Tuple 294 is sampled.
# Tuple 294 is labeled.
# Tuple 1965 is sampled.
# Tuple 1965 is labeled.

# %% [markdown]
# ### 7. Propagating User Labels
# Raha then propagates each user label through its cluster.

# %% [markdown]
# Raha then propagates each user label through its cluster.

# %%
app_1.propagate_labels(d)
# Out:
# The number of labeled data cells increased from 140 to 12426.

# %%
d.dataframe
# Out:
#      tuple_id                   src           flight sched_dep_time  \
# 0           1                    aa  AA-3859-IAH-ORD      7:10 a.m.
# 1           2                    aa  AA-1733-ORD-PHX      7:45 p.m.
# 2           3                    aa  AA-1640-MIA-MCO      6:30 p.m.
# 3           4                    aa   AA-518-MIA-JFK      6:40 a.m.
# 4           5                    aa  AA-3756-ORD-SLC     12:15 p.m.
# ...       ...                   ...              ...            ...
# 2371     2372  world-flight-tracker  UA-3099-PHX-PHL     11:55 a.m.
# 2372     2373  world-flight-tracker  AA-4198-ORD-CLE     10:40 a.m.
# 2373     2374  world-flight-tracker    CO-45-EWR-MIA      4:00 p.m.
# 2374     2375  world-flight-tracker  AA-3809-PHX-LAX      6:00 a.m.
# 2375     2376  world-flight-tracker    AA-59-JFK-SFO      7:10 a.m.
#
#      act_dep_time sched_arr_time act_arr_time
# 0       7:16 a.m.      9:40 a.m.    9:32 a.m.
# 1       7:58 p.m.     10:30 p.m.
# 2                      7:25 p.m.
# 3       6:54 a.m.      9:25 a.m.    9:28 a.m.
# 4      12:41 p.m.      2:45 p.m.    2:50 p.m.
# ...           ...            ...          ...
# 2371   11:43 a.m.      6:17 p.m.    5:38 p.m.
# 2372   10:54 a.m.     12:55 p.m.   12:50 p.m.
# 2373    3:58 p.m.      7:05 p.m.    6:36 p.m.
# 2374    6:10 a.m.      6:40 a.m.    6:19 a.m.
# 2375    7:39 a.m.     10:45 a.m.   11:12 a.m.
#
# [2376 rows x 7 columns]

# %% [markdown]
# ### 8. Predicting Labels of Data Cells
# Raha then trains and applies one classifier per data column to predict the label of the rest of data cells.

# %%
app_1.predict_labels(d)
# Out:
# A classifier is trained and applied on column 0.
# A classifier is trained and applied on column 1.
# A classifier is trained and applied on column 2.
# A classifier is trained and applied on column 3.
# A classifier is trained and applied on column 4.
# A classifier is trained and applied on column 5.
# A classifier is trained and applied on column 6.

# %% [markdown]
# ### 9. Storing Results
# Raha can also store the error detection results.

# %%
app_1.store_results(d)
# Out:
# The results are stored in ../datasets/flights/raha-baran-results-flights/error-detection/detection.dataset.

# %% [markdown]
# ### 10. Evaluating the Error Detection Task
# We can finally evaluate our error detection task.

# %%
p, r, f = d.get_data_cleaning_evaluation(d.detected_cells)[:3]
print("Raha's performance on {}:\nPrecision = {:.2f}\nRecall = {:.2f}\nF1 = {:.2f}".format(d.name, p, r, f))
# Out:
# Raha's performance on flights:
# Precision = 0.92
# Recall = 0.79
# F1 = 0.85

# %% [markdown]
# # Error Correction with Baran

# %% [markdown]
# ### 1. Instantiating the Correction Class
# We first instantiate the `Correction` class.

# %%
app_2 = raha.Correction()

# How many tuples would you label?
app_2.LABELING_BUDGET = 20

# Would you like to see the logs?
app_2.VERBOSE = True

# %% [markdown]
# ### 2. Initializing the Dataset Object
# We next initialize the dataset object.

# %%
d = app_2.initialize_dataset(d)
d.dataframe.head()
# Out:
#   tuple_id src           flight sched_dep_time act_dep_time sched_arr_time
# 0        1  aa  AA-3859-IAH-ORD      7:10 a.m.    7:16 a.m.      9:40 a.m.  \
# 1        2  aa  AA-1733-ORD-PHX      7:45 p.m.    7:58 p.m.     10:30 p.m.
# 2        3  aa  AA-1640-MIA-MCO      6:30 p.m.                   7:25 p.m.
# 3        4  aa   AA-518-MIA-JFK      6:40 a.m.    6:54 a.m.      9:25 a.m.
# 4        5  aa  AA-3756-ORD-SLC     12:15 p.m.   12:41 p.m.      2:45 p.m.
#
#   act_arr_time
# 0    9:32 a.m.
# 1
# 2
# 3    9:28 a.m.
# 4    2:50 p.m.

# %% [markdown]
# ### 3. Initializing the Error Corrector Models
# Baran initializes the error corrector models.

# %%
app_2.initialize_models(d)
# Out:
# The error corrector models are initialized.

# %% [markdown]
# ### 4. Interactive Tuple Sampling, Labeling, Model updating, Feature Generation, and Correction Prediction
# Baran then iteratively samples a tuple. We should label data cells of each sampled tuple. It then udpates the models accordingly and generates a feature vector for each pair of a data error and a correction candidate. Finally, it trains and applies a classifier to each data column to predict the final correction of each data error. Since we already labeled tuples for Raha, we use the same labeled tuples and do not label new tuples here.

# %%
# while len(d.labeled_tuples) < app_2.LABELING_BUDGET:
#     app_2.sample_tuple(d)
#     if d.has_ground_truth:
#         app_2.label_with_ground_truth(d)
#     else:
#         print("Label the dirty cells in the following sampled tuple.")
#         sampled_tuple = pandas.DataFrame(data=[d.dataframe.iloc[d.sampled_tuple, :]], columns=d.dataframe.columns)
#         IPython.display.display(sampled_tuple)
#         for j in range(d.dataframe.shape[1]):
#             cell = (d.sampled_tuple, j)
#             value = d.dataframe.iloc[cell]
#             correction = input("What is the correction for value '{}'? Type in the same value if it is not erronous.\n".format(value))
#             user_label = 1 if value != correction else 0
#             d.labeled_cells[cell] = [user_label, correction]
#         d.labeled_tuples[d.sampled_tuple] = 1
#     app_2.update_models(d)
#     app_2.predict_corrections(d)

for si in d.labeled_tuples:
    d.sampled_tuple = si
    app_2.update_models(d)
    app_2.predict_corrections(d)

# %% [markdown]
# ### 5. Storing Results
# Baran can also store the error correction results.

# %%
app_2.store_results(d)
# Out:
# The results are stored in ../datasets/flights/raha-baran-results-flights/error-correction/correction.dataset.

# %% [markdown]
# ### 6. Evaluating the Error Correction Task
# We can finally evaluate our error correction task.

# %%
p, r, f = d.get_data_cleaning_evaluation(d.corrected_cells)[-3:]
print("Baran's performance on {}:\nPrecision = {:.2f}\nRecall = {:.2f}\nF1 = {:.2f}".format(d.name, p, r, f))
# Out:
# Baran's performance on flights:
# Precision = 0.88
# Recall = 0.53
# F1 = 0.66
